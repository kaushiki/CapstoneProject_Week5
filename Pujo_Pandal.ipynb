# %% [markdown]
# Introduction-
# Durga Puja is one of the most famous festivals celebrated in West Bengal and particularly in Kolkata, in honour of Goddess Durga during the period of Navaratri.
# It is celebrated for 10 days, however starting from the sixth day until the ninth day, the Pandals with grand idols of Goddess Durga are open for visitors.
# The tenth day, also known as Dashami marks the Visarjan (immersion in water) of the idol with grand celebrations and processions.
# Every year people from all around the world travel to Kolkata to get a glimpse of this spectacular celebrations.
# Since Kolkata is a large city with a lot of pandals it becomes very  difficult for tourists  to know where to begin from and which pandals to see and how to go about.
# This will help the toursists in fuguring out how to go about the City of Joy, which pandals to visit where to get a quick bite from.
#
#
# Data and Methodolgy-
# My dataset has a list of the top pandals and it has been categorized into - into 3 segments - North Kolkata, South Kolkata and East Kolkata.
# I used the geopy library to get the latitudes and logitudes of each pandal and created a map of kolkata with the pandals superimposed on it.
# I used the same process to create maps of south, north and east Kolkata.
# I also used foursquare location data to explore all the venues near by each segment and to help locate places like restaurants and cafes to rest and refuel after all that walking and  exploring .

# %%
import numpy as np
# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# ...
# Solving environment: ...working...
# ...
#   - anaconda/win-64::openssl-1.1.1d-he774522_2
#   - defaults/win-64::openssl-1.1.1d-he774522_2done
#
# # All requested packages already installed.
#
# ...
# Solving environment: ...working...
# ...
#   - anaconda/win-64::openssl-1.1.1d-he774522_2
#   - defaults/win-64::openssl-1.1.1d-he774522_2done
#
# # All requested packages already installed.
#
# Folium installed
# Libraries imported.

# %% [markdown]
# Durga Puja is one of the most famous festivals celebrated in West Bengal and particularly in Kolkata, in honour of Goddess Durga during the period of Navaratri. It is celebrated for 10 days, however starting from the sixth day until the ninth day, the Pandals with grand idols of Goddess Durga are open for visitors. The tenth day, also known as Dashami marks the Visarjan (immersion in water) of the idol with grand celebrations and processions.

# %% [markdown]
# Here are the top 20 Durga Puja Pandal that you can visit-

# %%
import os
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import os
os.path.isfile(r"C:\Users\kaush\OneDrive\Desktop\pujo_pandalNew.csv")
df = pd.read_csv(r"C:\Users\kaush\OneDrive\Desktop\pujo_pandalNew.csv")
df.head
# Out:
# <bound method NDFrame.head of    Part of Kolkata            Pandal Name  Latitude  Longitude
# 0    South Kolkata    Ballygunge Cultural   22.5159    88.3557
# 1    South Kolkata      Bhabanipore Abasa   22.5277    88.3490
# 2    South Kolkata   Bhabanipore 75 Pally   22.5332    88.3457
# 3    North Kolkata    Beliaghata 33 Pally   22.5686    88.3912
# 4    South Kolkata        Deshapriya Park   22.5187    88.3558
# 5    South Kolkata      Ekdalia Evergreen   22.5212    88.3666
# 6    South Kolkata         Hindustan Park   22.5170    88.3634
# 7    North Kolkata  Hatibagan Nabin Pally   22.5960    88.3735
# 8    South Kolkata    Kidderpore 25 Pally   22.5392    88.3264
# 9    North Kolkata         Kumortoli Park   22.6012    88.3626
# 10   South Kolkata  Naktala Udayan Sangha   22.4744    88.3666
# 11   North Kolkata     Shovabazar Rajbari   22.5963    88.3672
# 12    East Kolkata     Sreebhumi Sporting   22.5993    88.4022
# ...

# %%
print('The dataframe has {} Parts of Kolkata and {} Pandal Name.'.format(
        len(df['Part of Kolkata'].unique()),
        df.shape[0]
    )
)
# Out:
# The dataframe has 3 Parts of Kolkata and 20 Pandal Name.

# %%
address = 'Kolkata, WB'

geolocator = Nominatim(user_agent="kol_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of City of Joy is  {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of City of Joy is  22.54541245, 88.3567751581234.

# %%
# create map of New York using latitude and longitude values
map_kolkata = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, part_kol, pandal_name in zip(df['Latitude'], df['Longitude'], df['Part of Kolkata'], df['Pandal Name']):
    label = '{}, {}'.format(pandal_name, part_kol)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_kolkata)  
    
map_kolkata
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Here are some of the Puja pandals of South Kolkata

# %%
southKolkata_data = df[df['Part of Kolkata'] == 'South Kolkata'].reset_index(drop=True)
southKolkata_data.head()
# Out:
#   Part of Kolkata           Pandal Name  Latitude  Longitude
# 0   South Kolkata   Ballygunge Cultural   22.5159    88.3557
# 1   South Kolkata     Bhabanipore Abasa   22.5277    88.3490
# 2   South Kolkata  Bhabanipore 75 Pally   22.5332    88.3457
# 3   South Kolkata       Deshapriya Park   22.5187    88.3558
# 4   South Kolkata     Ekdalia Evergreen   22.5212    88.3666

# %%
# create map of Manhattan using latitude and longitude values
map_southKolkata = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, pandal in zip(southKolkata_data['Latitude'], southKolkata_data['Longitude'], southKolkata_data['Pandal Name']):
    label = folium.Popup(pandal, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_southKolkata)  
    
map_southKolkata
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
CLIENT_ID = 'DCQFYDRPE1QQUFAV12S5JV24DYFRPCWZ4BWY1TRRCV40NRAZ' # your Foursquare ID
CLIENT_SECRET = '0BUQBE5WQFLROL5YRYFE5CBH3PEAYICWN1N2300PRQXSTLEC' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: DCQFYDRPE1QQUFAV12S5JV24DYFRPCWZ4BWY1TRRCV40NRAZ
# CLIENT_SECRET:0BUQBE5WQFLROL5YRYFE5CBH3PEAYICWN1N2300PRQXSTLEC

# %%
latitude = 22.5159
longitude = 88.3557
radius = 800
LIMIT=40
url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?client_id=DCQFYDRPE1QQUFAV12S5JV24DYFRPCWZ4BWY1TRRCV40NRAZ&client_secret=0BUQBE5WQFLROL5YRYFE5CBH3PEAYICWN1N2300PRQXSTLEC&ll=22.5159,88.3557&v=20180605&radius=800&limit=40'

# %%
import requests
results = requests.get(url).json()
'There are around {}  venues near South Kolkata.'.format(len(results['response']['groups'][0]['items']))
# Out:
# 'There are around 26  venues near South Kolkata.'

# %%
items = results['response']['groups'][0]['items']
items[0]
# Out:
# {'reasons': {'count': 0,
#   'items': [{'summary': 'This spot is popular',
#     'type': 'general',
#     'reasonName': 'globalInteractionReason'}]},
#  'venue': {'id': '51409ae6e4b0c2b51cfd04b0',
#   'name': 'Go Lebanese',
#   'location': {'address': '200, Sarat Bose Rd',
#    'lat': 22.51383054406505,
#    'lng': 88.35323095321655,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 22.51383054406505,
#      'lng': 88.35323095321655}],
#    'distance': 342,
#    'postalCode': '700029',
#    'cc': 'IN',
#    'city': 'Kolkata',
#    'state': 'West Bengal',
#    'country': 'India',
#    'formattedAddress': ['200, Sarat Bose Rd',
#     'Kolkata 700029',
#     'West Bengal',
#     'India']},
#   'categories': [{'id': '4bf58dd8d48988d10b941735',
#     'name': 'Falafel Restaurant',
#     'pluralName': 'Falafel Restaurants',
#     'shortName': 'Falafel',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/falafel_',
#      'suffix': '.png'},
# ...

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
dataframe = json_normalize(items) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories'] + [col for col in dataframe.columns if col.startswith('venue.location.')] + ['venue.id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# filter the category for each row
dataframe_filtered['venue.categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean columns
dataframe_filtered.columns = [col.split('.')[-1] for col in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                                name  \
# 0                                       Go Lebanese
# 1                                   Deshapriya Park
# 2                                   Triangular Park
# 3                                       Banana Leaf
# 4                                          Wise Owl
# 5                                   Cafe Coffee Day
# 6                               Sienna Store & Cafe
# 7                                         Cinépolis
# 8                                        Mrs Magpie
# 9                                         Oudh 1590
# 10                                  Cafe Coffee Day
# 11                                           Ammini
# 12                                      Xrong Place
# 13                                          Barista
# 14                                           Byloom
# 15                                           Hatari
# 16                                  Bhojohori Manna
# ...

# %% [markdown]
# After all the walking you can visit these resturants near South Kolkata for a scrumptious meal

# %%
southKolkata_resturant_data = dataframe_filtered[dataframe_filtered['categories'] == 'Vegetarian / Vegan Restaurant'].reset_index(drop=True)
southKolkata_resturant_data
# Out:
#       name                     categories              address        lat  \
# 0  Fillers  Vegetarian / Vegan Restaurant  26, Jatin Bagchi Rd  22.514698
#
#          lng                                     labeledLatLngs  distance  \
# 0  88.360628  [{'label': 'display', 'lat': 22.51469776790359...       524
#
#   postalCode  cc     city        state country  \
# 0     700029  IN  Kolkata  West Bengal   India
#
#                                     formattedAddress crossStreet  \
# 0  [26, Jatin Bagchi Rd, Kolkata 700029, West Ben...         NaN
#
#                          id
# 0  4cfe1d710df3236a057907aa

# %%
CLIENT_ID = 'DCQFYDRPE1QQUFAV12S5JV24DYFRPCWZ4BWY1TRRCV40NRAZ' # your Foursquare ID
CLIENT_SECRET = '0BUQBE5WQFLROL5YRYFE5CBH3PEAYICWN1N2300PRQXSTLEC' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: DCQFYDRPE1QQUFAV12S5JV24DYFRPCWZ4BWY1TRRCV40NRAZ
# CLIENT_SECRET:0BUQBE5WQFLROL5YRYFE5CBH3PEAYICWN1N2300PRQXSTLEC

# %%
latitude = 22.5159
longitude = 88.3557
search_query = 'Cafe'

radius = 500
LIMIT=40
print(search_query + ' .... OK!')
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query,radius, LIMIT)
url
results = requests.get(url).json()
results
# Out:
# Cafe .... OK!
# {'meta': {'code': 200, 'requestId': '5eca6e1147b43d0023a2aa1d'},
#  'response': {'venues': [{'id': '4dfc374ecc3f82583a4b089b',
#     'name': 'Cafe Chokolade',
#     'location': {'address': '16A, Lake View Rd',
#      'lat': 22.515708696252922,
#      'lng': 88.35567712783813,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 22.515708696252922,
#        'lng': 88.35567712783813}],
#      'distance': 21,
#      'postalCode': '700029',
#      'cc': 'IN',
#      'city': 'Kolkata',
#      'state': 'West Bengal',
#      'country': 'India',
#      'formattedAddress': ['16A, Lake View Rd',
#       'Kolkata 700029',
#       'West Bengal',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590324719',
# ...

# %%
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe
# Out:
#                           id                     name  \
# 0   4dfc374ecc3f82583a4b089b           Cafe Chokolade
# 1   4dd4064bd1643acaa1eea78a          Cafe Coffee Day
# 2   585bb392876ade0a35bf5761             Cafe Drifter
# 3   5bfc266f12f0a9002b1fa452         Cafe By The Lane
# 4   515addd1e4b03fc710a7c8ba          Cafe Coffee Day
# 5   5e25b3c61c522a00081caa48             Cafe Connect
# 6   56a5e393498ece5cadc47093              Cafe Bistro
# 7   554fd2b9498e8080190271a9      The Pool Board Cafe
# 8   5d44f05b816c150008582584     Cafe Shiisha Culture
# 9   5d3f1be43eeddd0008c317a0                 Cafe B60
# 10  52befcb2498ec248de6b3359                  Cafe 23
# 11  54027841498e21f6bdb7747d       Maniac Sports Cafe
# 12  5c0dcccc5c6838003969fe90        Little Mixup Cafe
# 13  5aa48fb7a35dce0b696705d5                  La Cafe
# 14  5260997511d2509f1f3a7e81           Paparazzi Cafe
# 15  5b965cbac0af57002c3f6d17    8th Day Cafe & Bakery
# ...
